# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4,])
plt.show()

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
#1st method 
fig = plt.figure() #create a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %%
#2nd method
fig = plt.figure() #creates figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
plt.close('all')# for closing previous subplots
#3rd method (recommended)
fig ,ax = plt.subplots()
ax.plot(x,y);#Adding Data
plt.show()
type(fig) , type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. Import matplotlib and get it ready for  plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

#1. Prepare Data
x = [1,2,3,4]
y = [11,22,33,44]

#2 Setup Plot
fig , ax = plt.subplots(figsize = (5,10))

#3 Plot Data
ax.plot(x,y)

#4 Customize Plot
ax.set(title = "Simple Plot",xlabel = "x-axis",ylabel = "y-axis")

#Save & Show 
fig.savefig("sample-plot.png")
plt.show()

# %% [markdown]
# ## Making figures with Numpy arrays
# We want :
# * Line Plot
# * Scatter Plot
# * Bar Plot
# * Histogram
# * Subplot

# %%
#Create some Data
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
# Plot the data and create a line plot
plt.close('all')
fig , ax =plt.subplots()
ax.plot(x , x**2)
plt.show()

# %%
# Use same data and create a Scatter plot
plt.close('all')
fig , ax =plt.subplots()
ax.plot(x ,np.exp(x));
plt.show()

# %%
#Another Scatter Plot
plt.close('all')
fig , ax = plt.subplots()
ax.plot(x,np.sin(x));
plt.show()

# %%
#Make Plot  from Dictionary
plt.close('all')
nut_butter_prices = {"Almond butter":10 , "Peanut butter":8 , "Cashew butter":12}
fig , ax = plt.subplots()
ax.bar( nut_butter_prices.keys(),height = nut_butter_prices.values());
ax.set(title = "Dan's Nut butter Store" , ylabel = "Price ($)");
plt.show()

# %%
plt.close('all')
fig , ax = plt.subplots()
ax.barh( list(nut_butter_prices.keys()),list( nut_butter_prices.values()));#Bar horizontal
ax.set(title = "Dan's Nut butter Store" , ylabel = "Price ($)");
plt.show()

# %%
#make some data for histograms and plot it
plt.close('all')
x= np.random.randn(1000)
fig , ax = plt.subplots()
ax.hist(x)
plt.show();

# %% [markdown]
# ## Two options for subplot

# %%
#Subplot option 1
plt.close('all')
fig , ((ax1 , ax2),(ax3,ax4)) = plt.subplots(nrows =2 , ncols =2 ,figsize=(10,5));
#Plot to each different axis 
ax1 .plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys() , nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
plt.show()

# %%
#SubPlots Option 2
plt.close('all')
fig , ax = plt .subplots(nrows = 2 ,
                         ncols =2 ,
                         figsize = (10,5))
#Plot to each Different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10) , np .random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

plt.show()

# %% [markdown]
# # plotting from pandas  dataFrame

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index = pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
#Remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum() 
car_sales ["Price"] = car_sales["Price"].astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Let's plot the total sales
plt.close('all')
car_sales.plot(x = "Sale Date" , y ="Total Sales");
plt.show()

# %%
#Scatter Plot
plt.close('all')
car_sales.plot(x= "Odometer (KM)" , y ="Price", kind = "scatter");
plt.show()

# %%
# How  about a bar graph
x = np.random.rand(10,4)
x
# Out:
# array([[0.1718269 , 0.80568651, 0.38057777, 0.85976188],
#        [0.05732745, 0.36759543, 0.13840664, 0.58377785],
#        [0.52431547, 0.08073489, 0.18368507, 0.12123521],
#        [0.63445556, 0.21006296, 0.83472596, 0.69037886],
#        [0.2613506 , 0.93693304, 0.398072  , 0.84346394],
#        [0.04227751, 0.55785569, 0.84883406, 0.30964547],
#        [0.86163271, 0.45539782, 0.16454884, 0.13313254],
#        [0.47954736, 0.0217806 , 0.77068611, 0.71174855],
#        [0.1337198 , 0.75356315, 0.23654085, 0.57231357],
#        [0.50660012, 0.45788134, 0.3010412 , 0.66055932]])

# %%
 #Turn it into a DataFrame
plt.close('all')
df = pd.DataFrame(x , columns = ['a','b','c','d']);
df.plot.bar()
plt.show()

# %%
df.plot(kind ='bar' )
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
plt.close('all')
car_sales.plot(x="Make" , y= "Odometer (KM)",kind = "bar")
plt.show()

# %%
# How about a histogram
plt.close('all')
##car_sales.plot(x="Make" , y= "Odometer (KM)",kind = "hist")
#car_sales["Odometer (KM)"].plot.hist();
car_sales["Odometer (KM)"].plot(kind = "hist")
plt.show()

# %%
plt.close('all')
car_sales["Odometer (KM)"].plot.hist(bins =10);# Bins is abucket for the values
plt.show()

# %%
# another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
#Create a histogram of the age column
plt.close('all')
heart_disease["age"].plot.hist(bins =10)
plt.show()

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize =(10,30),subplots = True);
plt.show()

# %% [markdown]
# ## Which one should you use?(pyplot vs matplotlib OO method)
# * When plotting something quickly its okay to use pyplot method
# * When Plotting Something more advanced , use the OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50
len(over_50)
# Out:
# 208

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#PyPlot Method
plt.close('all')
over_50.plot(kind = 'scatter',x = 'age' , y= 'chol' ,c ='target')
plt.show();

# %%
## OO method
plt.close('all')
fig , ax = plt.subplots(figsize =(10,6))
over_50.plot(kind = 'scatter',x = 'age' , y= 'chol' ,c ='target',ax=ax);
#ax . set_xlim([45,100])
plt.show();

# %%
plt.close('all')
## OO method from scratch
fig , ax = plt.subplots(figsize = (10,6))
# Plot Data
scatter = ax .scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
## customize the plot
ax .set(title = "Heart Disease and cholesterol Levels",
        xlabel ="Age",
        ylabel ="Cholesterol")
## Add a legend
ax.legend(*scatter.legend_elements(),title ="Target")
## Add a horizontal Line
ax.axhline(over_50["chol"].mean(),linestyle ="--")
plt.show()

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
## Subplot of chol , age ,thalach
plt.close('all')
fig ,(ax0 , ax1) = plt.subplots(nrows = 2, ncols =1,figsize =(10,10),sharex = True)# sharing same x label
#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
# Customize ax0
ax0.set(title = "Heart Disease and Cholesterol Levels",  ylabel ="Cholesterol"  )
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),linestyle ="--")
#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"])
# Customize ax1
ax1.set(title = "Heart Disease and Max Heart Rate", xlabel ="Age" , ylabel ="Thalach"  )
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),linestyle ="--")
# Add a Title to the Figure
fig.suptitle("Heart Disease Analysis",fontsize =16 ,fontweight='bold')
plt.show();

# %% [markdown]
# ## Customizing Matplot plots and gettiing stylish

# %%
plt.close('all')
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.close()
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
plt.close()
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use('seaborn-v0_8')
plt.close()
car_sales["Price"].plot()
plt.show()

# %%
plt.close()
car_sales.plot(x="Odometer (KM)" , y="Price" , kind = "scatter")

plt.show()

# %%
plt.style.use('ggplot')
plt.close()
car_sales["Price"].plot()
plt.show()

# %%
# Create some Data
x = np .random .randn(10,4)
x
# Out:
# array([[-0.01586979, -1.29514169,  0.54187098, -0.91322318],
#        [-0.66361171, -0.70333063,  1.78429835, -0.81863582],
#        [-0.75547283,  0.38121634,  0.02284484,  0.80262198],
#        [ 1.29940207, -0.13245841,  0.59403436,  0.49380051],
#        [-1.11699785,  0.368787  ,  0.60788177, -0.58554014],
#        [-0.35246676, -0.12353968,  1.07939187, -0.78895931],
#        [ 0.17002691, -1.34201352, -0.38938617,  2.33460254],
#        [-0.98339343,  0.46509431, -0.59766232,  1.29091312],
#        [-0.81028476,  1.63140487,  1.85180647,  0.08701841],
#        [ 0.52263599,  0.28955138, -0.11561431,  0.3858255 ]])

# %%
df = pd.DataFrame(x,columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.015870 -1.295142  0.541871 -0.913223
# 1 -0.663612 -0.703331  1.784298 -0.818636
# 2 -0.755473  0.381216  0.022845  0.802622
# 3  1.299402 -0.132458  0.594034  0.493801
# 4 -1.116998  0.368787  0.607882 -0.585540
# 5 -0.352467 -0.123540  1.079392 -0.788959
# 6  0.170027 -1.342014 -0.389386  2.334603
# 7 -0.983393  0.465094 -0.597662  1.290913
# 8 -0.810285  1.631405  1.851806  0.087018
# 9  0.522636  0.289551 -0.115614  0.385825

# %%
plt.close()
ax = df.plot(kind = 'bar')
type(ax)
plt.show()

# %%
#Customize our plot with the set() Method
ax = df.plot(kind = 'bar')
#Add some labels and a title 
ax.set(title = "Random Number Bar Graph from DataFrame", xlabel ="Row number" ,ylabel="Random number")
#Make Legend Visible
ax.legend().set_visible(True)
plt.show()

# %%
plt.style.use('seaborn-v0_8-whitegrid')
plt.close('all')
## OO method from scratch
fig , ax = plt.subplots(figsize = (10,6))
# Plot Data
scatter = ax .scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"], 
                       cmap="winter")#this changes color
## customize the plot
ax .set(title = "Heart Disease and cholesterol Levels",
        xlabel ="Age",
        ylabel ="Cholesterol")
## Add a legend
ax.legend(*scatter.legend_elements(),title ="Target")
## Add a horizontal Line
ax.axhline(over_50["chol"].mean(),linestyle ="--")
plt.show()

# %%
# Customizing the y and x axis
## Subplot of chol , age ,thalach
plt.close('all')
fig ,(ax0 , ax1) = plt.subplots(nrows = 2, ncols =1,figsize =(10,10),sharex = True)# sharing same x label
#Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap = "winter")
# Customize ax0
ax0.set(title = "Heart Disease and Cholesterol Levels",  ylabel ="Cholesterol"  )
ax0.set_xlim([50,80])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),linestyle ="--")
#Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"],
                     cmap = "winter")
# Customize ax1
ax1.set(title = "Heart Disease and Max Heart Rate", xlabel ="Age" , ylabel ="Thalach"  )
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),linestyle ="--")
# Add a Title to the Figure
fig.suptitle("Heart Disease Analysis",fontsize =16 ,fontweight='bold')
plt.show();

# %%
fig.savefig("heart disease analysis saved with plot code .png")
